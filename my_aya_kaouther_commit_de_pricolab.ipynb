# %% [markdown]
# <a href="https://colab.research.google.com/github/khalfaaya/my_projet_aya-kaouther-commit-de-pricolad/blob/main/my_aya_kaouther_commit_de_pricolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git init -b main
# Out:
# Initialized empty Git repository in /content/mon_projet/.git/

# %%
# !git config user.mane "aya khalfa koouther khalfaoui"
# !git config user.email "aya kaouther@gmail.com"

# %%
# !git add .
# !git commit -m "premier commit depuis Colab"
# Out:
# [main (root-commit) e36d848] premier commit depuis Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 Texet.txt

# %%
from getpass import getpass

token = getpass('Enter ton GitHub token : ')

import os
os.environ['GITHUB8TOKEN'] = token
# !git remote add origin http://$GITHUB_TOKEN@github.com/khalfaaya/my_projet_aya-kaouther-commit-de-pricolad.git
# !git push origin main
# Out:
# Enter ton GitHub token : ··········
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
